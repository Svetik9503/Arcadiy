# %%
## Задание 1
Переведите содержимое файла purchase_log.txt в словарь purchases вида:{‘1840e0b9d4’: ‘Продукты’, …}

# %%
import json

# %%
import json

i = 0
with open('purchase_log.txt', 'r', encoding="UTF-8") as f:
    for line in f:
        line = line.strip()
        dict_ = json.loads(line)
        print(dict_, type(dict_))  ## прошу напечатать полностью словари. ключ:значение, и тип данных
        i += 1
        if i > 5:
            break
# Out:
# {'user_id': 'user_id', 'category': 'category'} <class 'dict'>
# {'category': 'Продукты', 'user_id': '1840e0b9d4'} <class 'dict'>
# {'user_id': '4e4f90fcfb', 'category': 'Электроника'} <class 'dict'>
# {'user_id': 'afea8d72fc', 'category': 'Электроника'} <class 'dict'>
# {'user_id': '373a6055fe', 'category': 'Бытовая техника'} <class 'dict'>
# {'user_id': '9b2ab046f3', 'category': 'Электроника'} <class 'dict'>

# %%
import json
i = 0
with open('purchase_log.txt', 'r', encoding="UTF-8") as f:
    for line in f:
        line = line.strip()
        dict_ = json.loads(line)
        values = list(dict_.values()) ## прошу напечатать только значения
        print(values)
        i += 1
        if i > 5:
            break
# Out:
# ['user_id', 'category']
# ['Продукты', '1840e0b9d4']
# ['4e4f90fcfb', 'Электроника']
# ['afea8d72fc', 'Электроника']
# ['373a6055fe', 'Бытовая техника']
# ['9b2ab046f3', 'Электроника']
